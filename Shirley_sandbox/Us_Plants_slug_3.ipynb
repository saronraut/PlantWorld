# %%
from bs4 import BeautifulSoup
import pymongo
import pandas as pd
import numpy as np
import requests
import random
from sqlalchemy import create_engine
from config import trefle_key
token = trefle_key
import math
# Document Resource :https://docs.trefle.io/docs/examples/snippets
from datetime import datetime
from time import sleep
import time

# %%
zone_code = [601,602,603,604,605,606,325]

# %%
f'https://trefle.io/api/v1/plants/search?token={token}&q={search}'

# %%
state_slug = []

for zone in zone_code:
    url = f"https://trefle.io/api/v1/distributions/{zone}?token={token}"
    print("downloading: " + url)
    response = requests.get(url)
    data = response.json()['data']['children']
    
    for state in data:
        state_slug.append(state['slug'])
# Out:
# downloading: https://trefle.io/api/v1/distributions/601?token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# downloading: https://trefle.io/api/v1/distributions/602?token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# downloading: https://trefle.io/api/v1/distributions/603?token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# downloading: https://trefle.io/api/v1/distributions/604?token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# downloading: https://trefle.io/api/v1/distributions/605?token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# downloading: https://trefle.io/api/v1/distributions/606?token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# downloading: https://trefle.io/api/v1/distributions/325?token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g

# %%
# state_slug

# %%
# using the state slug, we need to loop through to get list of all the plants per state 
# would require us to loop through all the pages in the list 
links = []
for slug in state_slug:
    url = f"https://trefle.io/api/v1/distributions/{slug}?token={token}"
    response = requests.get(url)
   # print(url)
    data = response.json()['data']['links']['plants']
    x = links.append(data)
print(links)
# Out:
# ['/api/v1/distributions/was/plants', '/api/v1/distributions/wyo/plants', '/api/v1/distributions/ida/plants', '/api/v1/distributions/mnt/plants', '/api/v1/distributions/col/plants', '/api/v1/distributions/ore/plants', '/api/v1/distributions/iow/plants', '/api/v1/distributions/kan/plants', '/api/v1/distributions/mso/plants', '/api/v1/distributions/neb/plants', '/api/v1/distributions/sda/plants', '/api/v1/distributions/wis/plants', '/api/v1/distributions/ill/plants', '/api/v1/distributions/min/plants', '/api/v1/distributions/okl/plants', '/api/v1/distributions/nda/plants', '/api/v1/distributions/mas/plants', '/api/v1/distributions/rho/plants', '/api/v1/distributions/mic/plants', '/api/v1/distributions/ver/plants', '/api/v1/distributions/wva/plants', '/api/v1/distributions/mai/plants', '/api/v1/distributions/ohi/plants', '/api/v1/distributions/ini/plants', '/api/v1/distributions/nwh/plants', '/api/v1/distributions/cnt/plants', '/api/v1/distributions/nwj/plants', '/api/v1/distributions/nwy/plants', '/api/v1/distributions/pen/plants', '/api/v1/distributions/ari/plants', '/api/v1/distributions/nev/plants', '/api/v1/distributions/cal/plants', '/api/v1/distributions/uta/plants', '/api/v1/distributions/nwm/plants', '/api/v1/distributions/tex/plants', '/api/v1/distributions/mry/plants', '/api/v1/distributions/ark/plants', '/api/v1/distributions/nca/plants', '/api/v1/distributions/vrg/plants', '/api/v1/distributions/kty/plants', '/api/v1/distributions/fla/plants', '/api/v1/distributions/msi/plants', '/api/v1/distributions/ten/plants', '/api/v1/distributions/ala/plants', '/api/v1/distributions/wdc/plants', '/api/v1/distributions/del/plants', '/api/v1/distributions/geo/plants', '/api/v1/distributions/lou/plants', '/api/v1/distributions/sca/plants']

# %%
import time

print( "Start : %s" % time.ctime())
time.sleep( 5 )
print( "End : %s" % time.ctime())
# Out:
# Start : Fri Jan 22 23:12:19 2021
# End : Fri Jan 22 23:12:24 2021

# %%
state_slug_1 = ['was',
 'wyo',
 'ida',
 'mnt',
 'col',
 'ore',
 'iow',
 'kan',
 'mso',
 'neb',
 'sda',
 'wis',]

# %%
state_slug_1a = ['was',
 'wyo',
 'ida',
 'mnt',
 'col']

# %%
state_slug_1b = [
 'mso',
 'neb',
 'sda',
 'wis',]

# %%
state_slug_1c = [
 'ore',
 'iow',
 'kan']

# %%
state_slug_2 = ['ill',
 'min',
 'okl',
 'nda',
 'mas',
 'rho',
 'mic',
 'ver',
 'wva',
 'mai',
 'ohi',
 'ini',
 'nwh',
 'cnt',
 'nwj']

# %%
state_slug_3 = ['nwy',
 'pen',
 'ari',
 'nev',
 'cal',
 'uta',
 'nwm',
 'tex',
 'mry',
 'ark',
 'nca',
 'vrg',
 'kty',
 'fla',
 'msi',
 'ten',]

# %%
state_slug_4 = ['ala',
 'wdc',
 'del',
 'geo',
 'lou',
 'sca']

# %%
common_name = []
scientific_name = []
image_url = []
family_common_name = []
slug_list = []
year_list = []
plant_id = []
i=0

for slug in state_slug:
    url = f"https://trefle.io/api/v1/distributions/{slug}?token={token}"
    response = requests.get(url)   
#     print(f"Slug url is {url}")
    
    meta_data = response.json()['data']["species_count"]
#     print(f"meta_data is {meta_data}")

    
    pages = math.ceil(meta_data/20)
    
    pages = int(pages)
#     print(f"pages is {pages}")
#     pages = int(6)
    slug=slug
    
#         time.sleep(1)

    for page in range(1,pages):
        
        page_url = f"https://trefle.io/api/v1/distributions/{slug}/species?page={page}&token={token}"
        time.sleep(.5)
        print(page_url)
        try:
            results = requests.get(page_url)
            data = results.json()['data']
            names = [sub['common_name'] for sub in data]
            s_name = [sub['scientific_name'] for sub in data]
            image = [sub['image_url'] for sub in data]
            family = [sub['family_common_name'] for sub in data]
            year_in = [sub['year'] for sub in data]
            p_id = [sub['id'] for sub in data]
            slug_1 = [slug for d in data]

            plant_id.append(p_id)
            common_name.append(names)
            scientific_name.append(s_name)
            family_common_name.append(family)
            year_list.append(year_in)
            slug_list.append(slug_1)
            image_url.append(image)
        except:
            print(f'url failed {page_url}')
    time.sleep(45)
    print(f"Finished state {slug} with {pages} pages")
# Out:
# https://trefle.io/api/v1/distributions/was/species?page=1&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=2&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=3&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=4&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=5&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=6&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=7&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=8&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=9&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=10&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=11&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=12&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=13&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=14&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page=15&token=gIpeDhQj51LoZphqppfDxy1OSKQ1P8u9p8p5JUuZB_g
# https://trefle.io/api/v1/distributions/was/species?page
# 6678

# %%
def flatten_list(_2d_list):
    flat_list = []
    # Iterate throu the outer list
    for element in _2d_list:
        if type(element) is list:
            # If the element is of type list, iterate through the sublist
            for item in element:
                flat_list.append(item)
        else:
            flat_list.append(element)
    return flat_list

# %%
scientific_names_final = flatten_list(scientific_name)
common_name_final = flatten_list(common_name)
image_url_final = flatten_list(image_url)
family_common_name_final = flatten_list(family_common_name)
slug_list_final = flatten_list(slug_list)
year_final = flatten_list(year_list)
plant_id_final = flatten_list(plant_id)

# %%
len(slug_list_final)

# %%
# combine into one pandas dataframe
plants_returned = pd.DataFrame({"plant_id" : plant_id_final,
                                "common_name" : common_name_final,
                                "scientific_name": scientific_names_final,
                            "family_common_name": family_common_name_final,
                                "state_slug" : slug_list_final,
                                "year_found" : year_final,
                                    "image_url" : image_url_final})

# %%
plants_returned
# Out:
#         plant_id            common_name  \
# 0         190500        Stinging nettle
# 1         126957           Orchardgrass
# 2         167888    Narrowleaf plantain
# 3         137025             Red fescue
# 4         173910     Creeping buttercup
# ...          ...                    ...
# 133555   1236927                   None
# 133556   1237011                   None
# 133557    128397  Matting rosette grass
# 133558   1248295           Fan clubmoss
# 133559   1237125                   None
#
#                                    scientific_name family_common_name  \
# 0                                    Urtica dioica      Nettle family
# 1                               Dactylis glomerata       Grass family
# 2                              Plantago lanceolata    Plantain family
# 3                                    Festuca rubra       Grass family
# 4                                Ranunculus repens   Buttercup family
# ...                                            ...                ...
# 133555    Amsonia tabernaemontana var. salicifolia     Dogbane family
# 133556                                Avena sativa       Grass family
# 133557                          Panicum acuminatum       Grass family
# 133558                        Lycopodium digitatum   Club-moss family
# 133559  Asplenium platyneuron var. bacculum-rubrum  Spleenwort family
#
#        state_slug  year_found  \
# 0             was      1753.0
# 1             was      1753.0
# 2             was      1753.0
# 3             was      1753.0
# 4             was      1753.0
# ...           ...         ...
# 133555        sca      1928.0
# 133556        sca      1753.0
# 133557        sca      1974.0
# 133558        sca      1848.0
# 133559        sca      1936.0
#
#                                                 image_url
# 0       https://bs.floristic.org/image/o/85256a1c2c098...
# 1       https://bs.floristic.org/image/o/428f40dadfa02...
# 2       https://bs.floristic.org/image/o/78a8374f009e6...
# 3       https://bs.floristic.org/image/o/0b932c8a275ef...
# 4       https://bs.floristic.org/image/o/c6d9a5222b6ef...
# ...                                                   ...
# 133555                                               None
# 133556  https://d2seqvvyy3b8p2.cloudfront.net/1196d067...
# 133557  https://d2seqvvyy3b8p2.cloudfront.net/aab54e17...
# 133558                                               None
# 133559                                               None
#
# [133560 rows x 7 columns]

# %%
plants_returned.to_csv(r'C:\Users\Shirley\Desktop\Homework_BC_SJL\18-Homework-project-2\PlantWorld\shirley_sandbox\data_out\slug_final.csv', index=False)
