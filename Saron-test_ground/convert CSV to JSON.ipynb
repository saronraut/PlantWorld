# %%
import pandas as pd
import json

# %%
df = pd.read_csv("flowering.csv")

# %%
df = df[["Common Name", "Scientific Name","Family Common Name", "Duration","Growth Habit",
        "Active Growth Period","Flower Color", "Foliage Color", "Growth Rate", "Height, Mature (feet)",
        "Toxicity","Drought Tolerance", "Shade Tolerance", "Bloom Period", "Palatable Human"]]

# %%
df
# Out:
#               Common Name                      Scientific Name  \
# 0      flexible ceanothus                  Ceanothus ×flexilis
# 1                rosemary               Rosmarinus officinalis
# 2      common threesquare  Schoenoplectus pungens var. pungens
# 3       common periwinkle                          Vinca minor
# 4      California red fir                      Abies magnifica
# ...                   ...                                  ...
# 30572    Arizona siltbush     Zuckia brandegeei var. arizonica
# 30573            siltbush    Zuckia brandegeei var. brandegeei
# 30574  Plummer's siltbush      Zuckia brandegeei var. plummeri
# 30575           beancaper                          Zygophyllum
# 30576    Syrian beancaper                   Zygophyllum fabago
#
#          Family Common Name   Duration         Growth Habit  \
# 0          Buckthorn family  Perennial                Shrub
# 1               Mint family  Perennial      Shrub, Subshrub
# 2              Sedge family  Perennial            Graminoid
# 3            Dogbane family  Perennial      Forb/herb, Vine
# 4               Pine family  Perennial                 Tree
# ...                     ...        ...                  ...
# 30572      Goosefoot family  Perennial      Shrub, Subshrub
# 30573      Goosefoot family  Perennial      Subshrub, Shrub
# 30574      Goosefoot family  Perennial      Shrub, Subshrub
# 30575  Creosote-bush family        NaN                  NaN
# 30576  Creosote-bush family  Perennial  Subshrub, Forb/herb
#
#       Active Growth Period Flower Color Foliage Color Growth Rate  \
# 0        Spring and Summer         Blue    Dark Green    Moderate
# 1        Spring and Summer         Blue    Dark Green    Moderate
# 2                   Summer         Blue    Dark Green    Moderate
# 3        Spring and Summer         Blue    Dark Green    Moderate
# 4        Spring and Summer        Brown    Dark Green        Slow
# ...                    ...          ...           ...         ...
# 30572                  NaN          NaN           NaN         NaN
# 30573                  NaN          NaN           NaN         NaN
# 30574                  NaN          NaN           NaN         NaN
# 30575                  NaN          NaN           NaN         NaN
# 30576                  NaN          NaN           NaN         NaN
#
#        Height, Mature (feet)  Toxicity Drought Tolerance Shade Tolerance  \
# 0                        1.0    Slight              High        Tolerant
# 1                        5.0      None              High      Intolerant
# 2                        4.9      None               Low      Intolerant
# 3                        0.3  Moderate            Medium        Tolerant
# 4                      150.0      None               Low        Tolerant
# ...                      ...       ...               ...             ...
# 30572                    NaN       NaN               NaN             NaN
# 30573                    NaN       NaN               NaN             NaN
# 30574                    NaN       NaN               NaN             NaN
# 30575                    NaN       NaN               NaN             NaN
# 30576                    NaN       NaN               NaN             NaN
#
#        Bloom Period Palatable Human
# 0      Early Summer              No
# 1        Mid Spring             Yes
# 2       Late Spring              No
# 3      Early Summer              No
# 4       Late Spring              No
# ...             ...             ...
# 30572           NaN             NaN
# 30573           NaN             NaN
# 30574           NaN             NaN
# 30575           NaN             NaN
# 30576           NaN             NaN
#
# [30577 rows x 15 columns]

# %%
df.head()
# Out:
#           Common Name                      Scientific Name Family Common Name  \
# 0  flexible ceanothus                  Ceanothus ×flexilis   Buckthorn family
# 1            rosemary               Rosmarinus officinalis        Mint family
# 2  common threesquare  Schoenoplectus pungens var. pungens       Sedge family
# 3   common periwinkle                          Vinca minor     Dogbane family
# 4  California red fir                      Abies magnifica        Pine family
#
#     Duration     Growth Habit Active Growth Period Flower Color Foliage Color  \
# 0  Perennial            Shrub    Spring and Summer         Blue    Dark Green
# 1  Perennial  Shrub, Subshrub    Spring and Summer         Blue    Dark Green
# 2  Perennial        Graminoid               Summer         Blue    Dark Green
# 3  Perennial  Forb/herb, Vine    Spring and Summer         Blue    Dark Green
# 4  Perennial             Tree    Spring and Summer        Brown    Dark Green
#
#   Growth Rate  Height, Mature (feet)  Toxicity Drought Tolerance  \
# 0    Moderate                    1.0    Slight              High
# 1    Moderate                    5.0      None              High
# 2    Moderate                    4.9      None               Low
# 3    Moderate                    0.3  Moderate            Medium
# 4        Slow                  150.0      None               Low
#
#   Shade Tolerance  Bloom Period Palatable Human
# 0        Tolerant  Early Summer              No
# 1      Intolerant    Mid Spring             Yes
# 2      Intolerant   Late Spring              No
# 3        Tolerant  Early Summer              No
# 4        Tolerant   Late Spring              No

# %%
df_2= df.rename(columns={"Common Name": "common_name", "Scientific Name": "scientific_name",
          "Family Common Name": "family_name", "Growth Habit":"grwth_habit", "Active Growth Period": "Actv_grwth_prd",
           "Flower Color": "flower_color", "Foliage Color": "fooliage_color", "Growth Rate": "grwth_rate",
           "Height, Mature (feet)":"height_ft", "Drought Tolerance": "drought_tolerance", "Shade Tolerance": "shade_tolerace",
           "Bloom Period" : "bloom_period", "Palatable Human" : "palatable_human"
          })

# %%
df_3 = df_2.dropna()

# %%
df_3
# Out:
#                 common_name                      scientific_name  \
# 0        flexible ceanothus                  Ceanothus ×flexilis
# 1                  rosemary               Rosmarinus officinalis
# 2        common threesquare  Schoenoplectus pungens var. pungens
# 3         common periwinkle                          Vinca minor
# 4        California red fir                      Abies magnifica
# ...                     ...                                  ...
# 1972              jack pine                      Pinus banksiana
# 1973          balsam poplar                  Populus balsamifera
# 1975         shining willow                         Salix lucida
# 1976          yellow willow                          Salix lutea
# 1978  littleleaf horsebrush                  Tetradymia glabrata
#
#            family_name   Duration      grwth_habit        Actv_grwth_prd  \
# 0     Buckthorn family  Perennial            Shrub     Spring and Summer
# 1          Mint family  Perennial  Shrub, Subshrub     Spring and Summer
# 2         Sedge family  Perennial        Graminoid                Summer
# 3       Dogbane family  Perennial  Forb/herb, Vine     Spring and Summer
# 4          Pine family  Perennial             Tree     Spring and Summer
# ...                ...        ...              ...                   ...
# 1972       Pine family  Perennial             Tree     Spring and Summer
# 1973     Willow family  Perennial             Tree     Spring and Summer
# 1975     Willow family  Perennial      Shrub, Tree     Spring and Summer
# 1976     Willow family  Perennial      Tree, Shrub     Spring and Summer
# 1978      Aster family  Perennial  Subshrub, Shrub  Spring, Summer, Fall
#
#      flower_color fooliage_color grwth_rate  height_ft  Toxicity  \
# 0            Blue     Dark Green   Moderate        1.0    Slight
# 1            Blue     Dark Green   Moderate        5.0      None
# 2            Blue     Dark Green   Moderate        4.9      None
# 3            Blue     Dark Green   Moderate        0.3  Moderate
# 4           Brown     Dark Green       Slow      150.0      None
# ...           ...            ...        ...        ...       ...
# 1972       Yellow   Yellow-Green      Rapid       80.0      None
# 1973       Yellow   Yellow-Green      Rapid       80.0      None
# 1975       Yellow   Yellow-Green      Rapid       13.0      None
# 1976       Yellow   Yellow-Green      Rapid       16.0      None
# 1978       Yellow   Yellow-Green       Slow       12.0    Severe
#
#      drought_tolerance shade_tolerace  bloom_period palatable_human
# 0                 High       Tolerant  Early Summer              No
# 1                 High     Intolerant    Mid Spring             Yes
# 2                  Low     Intolerant   Late Spring              No
# 3               Medium       Tolerant  Early Summer              No
# 4                  Low       Tolerant   Late Spring              No
# ...                ...            ...           ...             ...
# 1972               Low     Intolerant   Late Spring              No
# 1973               Low     Intolerant   Late Spring              No
# 1975               Low   Intermediate        Spring              No
# 1976               Low   Intermediate        Spring              No
# 1978              High     Intolerant   Late Summer              No
#
# [1819 rows x 15 columns]

# %%
result = df_3.to_json(r'plantinfo.json', orient="records")
# parsed = json.loads(result)
# json.dumps(parsed)
