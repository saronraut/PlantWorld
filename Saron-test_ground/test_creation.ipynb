# %%
from bs4 import BeautifulSoup
import pymongo
import pandas as pd
import requests
from sqlalchemy import create_engine
import json
from datetime import datetime
import time
from time import sleep

# %%
test_df = pd.read_csv("test.csv")

# %%
test_df
# Out:
#       species_common_name  species_family  \
# 0         Stinging nettle      Urticaceae
# 1            Orchardgrass         Poaceae
# 2     Narrowleaf plantain  Plantaginaceae
# 3              Red fescue         Poaceae
# 4      Creeping buttercup   Ranunculaceae
# 5      Common velvetgrass         Poaceae
# 6        Oneseed hawthorn        Rosaceae
# 7          Tall buttercup   Ranunculaceae
# 8             Common rush       Juncaceae
# 9       Sweet vernalgrass         Poaceae
# 10        Common plantain  Plantaginaceae
# 11            Common reed         Poaceae
# 12    Bird's-foot trefoil        Fabaceae
# 13        Rough bluegrass         Poaceae
# 14             Ground ivy       Lamiaceae
# 15  European mountain ash        Rosaceae
# 16            Stickywilly       Rubiaceae
#
#                                             image_url           species_slug  \
# 0   https://bs.floristic.org/image/o/85256a1c2c098...          urtica-dioica
# 1   https://bs.floristic.org/image/o/428f40dadfa02...     dactylis-glomerata
# 2   https://bs.floristic.org/image/o/78a8374f009e6...    plantago-lanceolata
# 3   https://bs.floristic.org/image/o/0b932c8a275ef...          festuca-rubra
# 4   https://bs.floristic.org/image/o/c6d9a5222b6ef...      ranunculus-repens
# 5   https://bs.floristic.org/image/o/46619775d4319...         holcus-lanatus
# 6   https://bs.floristic.org/image/o/26b1520c79917...     crataegus-monogyna
# 7   https://bs.floristic.org/image/o/8390d605e1947...       ranunculus-acris
# 8   https://bs.floristic.org/image/o/93041212342d6...         juncus-effusus
# 9   https://bs.floristic.org/image/o/fcf64ef0676db...  anthoxanthum-odoratum
# 10  https://bs.floristic.org/image/o/36c2225c7d24a...         plantago-major
# 11  https://bs.floristic.org/image/o/1155e16145883...   phragmites-australis
# 12  https://bs.floristic.org/image/o/c2180ef57b83b...     lotus-corniculatus
# 13  https://bs.floristic.org/image/o/8e4f8472f36f3...          poa-trivialis
# 14  https://bs.floristic.org/image/o/d7aa2ca54f628...     glechoma-hederacea
# 15  https://bs.floristic.org/image/o/63073d2fbf45b...       sorbus-aucuparia
# 16  https://bs.floristic.org/image/o/dda8d72438e46...         galium-aparine
#
#     discovery_year    species_scntfc_name species_fmly_cmmn_name state_slug  \
# 0             1753          Urtica dioica          Nettle family        was
# 1             1753     Dactylis glomerata           Grass family        was
# 2             1753    Plantago lanceolata        Plantain family        was
# 3             1753          Festuca rubra           Grass family        was
# 4             1753      Ranunculus repens       Buttercup family        was
# 5             1753         Holcus lanatus           Grass family        was
# 6             1775     Crataegus monogyna            Rose family        was
# 7             1753       Ranunculus acris       Buttercup family        was
# 8             1753         Juncus effusus            Rush family        was
# 9             1753  Anthoxanthum odoratum           Grass family        was
# 10            1753         Plantago major        Plantain family        was
# 11            1841   Phragmites australis           Grass family        was
# 12            1753     Lotus corniculatus             Pea family        was
# 13            1753          Poa trivialis           Grass family        was
# 14            1753     Glechoma hederacea            Mint family        was
# 15            1753       Sorbus aucuparia            Rose family        was
# 16            1753         Galium aparine          Madder family        was
#
#    toxicity  edible growth_rate bloom_months
# 0      high    True        slow          jan
# 1       low   False        slow          feb
# 2      high   False        Fast         marc
# 3    medium   False        Slow          apr
# 4    medium   False      Medium         june
# 5       NaN   False      Medium         july
# 6       NaN   False      Medium          jan
# 7      high   False        slow          feb
# 8       low   False        fast         marc
# 9      high    True        fast          apr
# 10   medium    True        fast         june
# 11   medium    True        slow         july
# 12      NaN    True        slow          jan
# 13      NaN    True        fast          feb
# 14     high    True        fast         marc
# 15      low   False        slow          apr
# 16     high   False      medium         june

# %%
test_df_dict = test_df.to_dict()

# %%
test_df_dict
# Out:
# {'species_common_name': {0: 'Stinging nettle',
#   1: 'Orchardgrass',
#   2: 'Narrowleaf plantain',
#   3: 'Red fescue',
#   4: 'Creeping buttercup',
#   5: 'Common velvetgrass',
#   6: 'Oneseed hawthorn',
#   7: 'Tall buttercup',
#   8: 'Common rush',
#   9: 'Sweet vernalgrass',
#   10: 'Common plantain',
#   11: 'Common reed',
#   12: "Bird's-foot trefoil",
#   13: 'Rough bluegrass',
#   14: 'Ground ivy',
#   15: 'European mountain ash',
#   16: 'Stickywilly'},
#  'species_family': {0: 'Urticaceae',
#   1: 'Poaceae',
#   2: 'Plantaginaceae',
#   3: 'Poaceae',
#   4: 'Ranunculaceae',
#   5: 'Poaceae',
#   6: 'Rosaceae',
#   7: 'Ranunculaceae',
#   8: 'Juncaceae',
#   9: 'Poaceae',
#   10: 'Plantaginaceae',
#   11: 'Poaceae',
#   12: 'Fabaceae',
#   13: 'Poaceae',
#   14: 'Lamiaceae',
#   15: 'Rosaceae',
#   16: 'Rubiaceae'},
#  'image_url': {0: 'https://bs.floristic.org/image/o/85256a1c2c098e254fefe05040626a4df49ce248',
#   1: 'https://bs.floristic.org/image/o/428f40dadfa0281dc890ead17fcd07882f9efb09',
#   2: 'https://bs.floristic.org/image/o/78a8374f009e6ed2dc71ca17d18e4271ea0a2a7b',
#   3: 'https://bs.floristic.org/image/o/0b932c8a275efc79f473a71bec20d6f15e9b6b90',
#   4: 'https://bs.floristic.org/image/o/c6d9a5222b6ef0e3a7bdef3350278718d3097bce',
#   5: 'https://bs.floristic.org/image/o/46619775d4319328b2fad6f1ba876ccca2d03534',
#   6: 'https://bs.floristic.org/image/o/26b1520c799177ee1b7c4a27f9f46c4ace617dd2',
#   7: 'https://bs.floristic.org/image/o/8390d605e1947cb44e24af9492f96df4a34e8ca8',
#   8: 'https://bs.floristic.org/image/o/93041212342d6e8f9f544fd55000c037485a360e',
#   9: 'https://bs.floristic.org/image/o/fcf64ef0676db8ca9d2abf4017f5b8211b10e0b1',
#   10: 'https://bs.floristic.org/image/o/36c2225c7d24a897eaf055e99eac26b3f5ceffa3',
#   11: 'https://bs.floristic.org/image/o/1155e1614588374ce93aedb701ae8483e2cae45f',
#   12: 'https://bs.floristic.org/image/o/c2180ef57b83b419e4b851c058003d56ad2c6bbe',
#   13: 'https://bs.floristic.org/image/o/8e4f8472f36f36175a8d2fca4723059699f9d46e',
#   14: 'https://bs.floristic.org/image/o/d7aa2ca54f628e1f5a67dd672aeebb006d281a9b',
#   15: 'https://bs.floristic.org/image/o/63073d2fbf45b90701279405ecc2eec0272906ed',
#   16: 'https://bs.floristic.org/image/o/dda8d72438e461abaca1e717c43b1555d2727bc8'},
#  'species_slug': {0: 'urtica-dioica',
#   1: 'dactylis-glomerata',
#   2: 'plantago-lanceolata',
#   3: 'festuca-rubra',
#   4: 'ranunculus-repens',
#   5: 'holcus-lanatus',
#   6: 'crataegus-monogyna',
#   7: 'ranunculus-acris',
#   8: 'juncus-effusus',
#   9: 'anthoxanthum-odoratum',
#   10: 'plantago-major',
#   11: 'phragmites-australis',
#   12: 'lotus-corniculatus',
#   13: 'poa-trivialis',
#   14: 'glechoma-hederacea',
#   15: 'sorbus-aucuparia',
#   16: 'galium-aparine'},
#  'discovery_year': {0: 1753,
#   1: 1753,
#   2: 1753,
#   3: 1753,
#   4: 1753,
#   5: 1753,
#   6: 1775,
#   7: 1753,
#   8: 1753,
#   9: 1753,
#   10: 1753,
#   11: 1841,
#   12: 1753,
#   13: 1753,
#   14: 1753,
#   15: 1753,
#   16: 1753},
#  'species_scntfc_name': {0: 'Urtica dioica',
#   1: 'Dactylis glomerata',
#   2: 'Plantago lanceolata',
#   3: 'Festuca rubra',
#   4: 'Ranunculus repens',
#   5: 'Holcus lanatus',
#   6: 'Crataegus monogyna',
#   7: 'Ranunculus acris',
#   8: 'Juncus effusus',
#   9: 'Anthoxanthum odoratum',
#   10: 'Plantago major',
#   11: 'Phragmites australis',
#   12: 'Lotus corniculatus',
#   13: 'Poa trivialis',
#   14: 'Glechoma hederacea',
#   15: 'Sorbus aucuparia',
#   16: 'Galium aparine'},
#  'species_fmly_cmmn_name': {0: 'Nettle family',
#   1: 'Grass family',
#   2: 'Plantain family',
#   3: 'Grass family',
#   4: 'Buttercup family',
#   5: 'Grass family',
#   6: 'Rose family',
#   7: 'Buttercup family',
#   8: 'Rush family',
#   9: 'Grass family',
#   10: 'Plantain family',
#   11: 'Grass family',
#   12: 'Pea family',
#   13: 'Grass family',
#   14: 'Mint family',
#   15: 'Rose family',
#   16: 'Madder family'},
#  'state_slug': {0: 'was',
#   1: 'was',
#   2: 'was',
#   3: 'was',
#   4: 'was',
#   5: 'was',
#   6: 'was',
#   7: 'was',
#   8: 'was',
#   9: 'was',
#   10: 'was',
#   11: 'was',
#   12: 'was',
#   13: 'was',
#   14: 'was',
#   15: 'was',
#   16: 'was'},
#  'toxicity': {0: 'high',
#   1: 'low',
#   2: 'high',
#   3: 'medium',
#   4: 'medium',
#   5: nan,
#   6: nan,
#   7: 'high',
#   8: 'low',
#   9: 'high',
#   10: 'medium',
#   11: 'medium',
#   12: nan,
#   13: nan,
#   14: 'high',
#   15: 'low',
#   16: 'high'},
#  'edible': {0: True,
#   1: False,
#   2: False,
#   3: False,
#   4: False,
#   5: False,
#   6: False,
#   7: False,
#   8: False,
#   9: True,
#   10: True,
#   11: True,
#   12: True,
#   13: True,
#   14: True,
#   15: False,
#   16: False},
#  'growth_rate': {0: 'slow',
#   1: 'slow',
#   2: 'Fast',
#   3: 'Slow',
#   4: 'Medium',
#   5: 'Medium',
#   6: 'Medium',
#   7: 'slow',
#   8: 'fast',
#   9: 'fast',
#   10: 'fast',
#   11: 'slow',
#   12: 'slow',
#   13: 'fast',
#   14: 'fast',
#   15: 'slow',
#   16: 'medium'},
#  'bloom_months': {0: 'jan',
#   1: 'feb',
#   2: 'marc',
#   3: 'apr',
#   4: 'june',
#   5: 'july',
#   6: 'jan',
#   7: 'feb',
#   8: 'marc',
#   9: 'apr',
#   10: 'june',
#   11: 'july',
#   12: 'jan',
#   13: 'feb',
#   14: 'marc',
#   15: 'apr',
#   16: 'june'}}

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.table_test
collection = db.test_create

# %%
collection.insert_many(test_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-0b4afdbac898> in <module>
# ----> 1 collection.insert_many(test_df)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     743         .. versionadded:: 3.0
#     744         """
# --> 745         if not isinstance(documents, abc.Iterable) or not documents:
#     746             raise TypeError("documents must be a non-empty list")
#     747         inserted_ids = []
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476
#    1477     def __nonzero__(self):
# -> 1478         raise ValueError(
#    1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
